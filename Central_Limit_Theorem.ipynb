# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kintarou/django-starter/blob/master/Central_Limit_Theorem.ipynb)

# %%
import random
import pylab

def variance(X):
  mean=sum(X)/len(X)
  tot=0.0
  for x in X:
    tot+=(x-mean)**2
  return tot/len(X)
def plotMeans(numDicePerTrial, numDiceThrown, numBins, legend, color, style):
  means=[]
  numTrials=numDiceThrown//numDicePerTrial
  for i in range(numTrials):
    vals=0
    for j in range(numDicePerTrial):
      vals+=5*random.random()
    means.append(vals/numDicePerTrial)
  pylab.hist(means, numBins, color=color, label=legend, weights=pylab.array(len(means)*[1])/len(means), hatch=style)
  return sum(means)/len(means), variance(means)
mean, var = plotMeans(1, 100000, 11, 'I die', 'w', '*')
print('Mean of rolling I die =', round(mean, 4), 'Variance =', round(var, 4))
mean, var = plotMeans(100, 100000, 11, 'Mean of 100 dice', 'w', '//')
print('Mean of rolling 100 dice =', round(mean, 4), 'Variance =', round(var, 4))
pylab.title('Rolling Continuous Dice')
pylab.xlabel('Value')
pylab.ylabel('Probability')
pylab.legend()
# Out:
# Mean of rolling I die = 2.4986 Variance = 2.09
# Mean of rolling 100 dice = 2.5026 Variance = 0.0191
