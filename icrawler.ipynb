# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kintarou/django-starter/blob/master/icrawler.ipynb)

# %%
# !pip install icrawler
# Out:
# ...
#     100% |████████████████████████████████| 5.9MB 4.9MB/s
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

crawler = GoogleImageCrawler(storage={"root_dir": "images"})
crawler.crawl(keyword="電車", max_num=100)
# Out:
# 2018-07-17 01:56:10,915 - INFO - icrawler.crawler - start crawling...
# 2018-07-17 01:56:10,917 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2018-07-17 01:56:10,920 - INFO - feeder - thread feeder-001 exit
# 2018-07-17 01:56:10,920 - INFO - icrawler.crawler - starting 1 parser threads...
# 2018-07-17 01:56:10,923 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2018-07-17 01:56:11,079 - INFO - parser - parsing result page https://www.google.com/search?q=%E9%9B%BB%E8%BB%8A&ijn=0&start=0&tbs=&tbm=isch
# 2018-07-17 01:56:11,122 - INFO - downloader - skip downloading file 000001.jpg
# 2018-07-17 01:56:11,124 - INFO - downloader - skip downloading file 000002.jpg
# 2018-07-17 01:56:11,128 - INFO - downloader - skip downloading file 000003.jpg
# 2018-07-17 01:56:11,131 - INFO - downloader - skip downloading file 000004.jpg
# 2018-07-17 01:56:11,133 - INFO - downloader - skip downloading file 000005.jpg
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

crawler = GoogleImageCrawler(storage={"root_dir": "images"})
crawler.crawl(keyword="鉄道", max_num=100)
# Out:
# 2018-07-17 02:10:00,773 - INFO - icrawler.crawler - start crawling...
# 2018-07-17 02:10:00,774 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2018-07-17 02:10:00,776 - INFO - feeder - thread feeder-001 exit
# 2018-07-17 02:10:00,776 - INFO - icrawler.crawler - starting 1 parser threads...
# 2018-07-17 02:10:00,779 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2018-07-17 02:10:01,117 - INFO - parser - parsing result page https://www.google.com/search?q=%E9%89%84%E9%81%93&ijn=0&start=0&tbs=&tbm=isch
# 2018-07-17 02:10:01,157 - INFO - downloader - skip downloading file 000001.jpg
# 2018-07-17 02:10:01,159 - INFO - downloader - skip downloading file 000002.jpg
# 2018-07-17 02:10:01,160 - INFO - downloader - skip downloading file 000003.jpg
# 2018-07-17 02:10:01,166 - INFO - downloader - skip downloading file 000004.jpg
# 2018-07-17 02:10:01,170 - INFO - downloader - skip downloading file 000005.jpg
# ...

# %%
from icrawler.builtin import GoogleImageCrawler

crawler = GoogleImageCrawler(storage={"root_dir": "images"})
crawler.crawl(keyword="近鉄", max_num=100)
# Out:
# 2018-07-17 02:12:08,197 - INFO - icrawler.crawler - start crawling...
# 2018-07-17 02:12:08,198 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2018-07-17 02:12:08,200 - INFO - feeder - thread feeder-001 exit
# 2018-07-17 02:12:08,200 - INFO - icrawler.crawler - starting 1 parser threads...
# 2018-07-17 02:12:08,208 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2018-07-17 02:12:08,591 - INFO - parser - parsing result page https://www.google.com/search?q=%E8%BF%91%E9%89%84&ijn=0&start=0&tbs=&tbm=isch
# 2018-07-17 02:12:08,628 - INFO - downloader - skip downloading file 000001.jpg
# 2018-07-17 02:12:08,632 - INFO - downloader - skip downloading file 000002.jpg
# 2018-07-17 02:12:08,635 - INFO - downloader - skip downloading file 000003.jpg
# 2018-07-17 02:12:08,638 - INFO - downloader - skip downloading file 000004.jpg
# 2018-07-17 02:12:08,639 - INFO - downloader - skip downloading file 000005.jpg
# ...
