# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kintarou/django-starter/blob/master/electric_regression.ipynb)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7fbe8efa-65b4-4280-8fd6-4d8bcea91479" name="files[]" multiple disabled />
#      <output id="result-7fbe8efa-65b4-4280-8fd6-4d8bcea91479">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving shikoku_electricity_2012.csv to shikoku_electricity_2012.csv

# %%
import pandas as pd
pd.read_csv('shikoku_electricity_2012.csv', skiprows=3, names=['DATE','TIME','consumption'],parse_dates={'date_hour':['DATE','TIME']}, index_col='date_hour')
# Out:
#                      consumption
# date_hour
# 2012-07-02 00:00:00          261
# 2012-07-02 01:00:00          256
# 2012-07-02 02:00:00          269
# 2012-07-02 03:00:00          289
# 2012-07-02 04:00:00          297
# 2012-07-02 05:00:00          289
# 2012-07-02 06:00:00          282
# 2012-07-02 07:00:00          297
# 2012-07-02 08:00:00          344
# 2012-07-02 09:00:00          378
# 2012-07-02 10:00:00          395
# 2012-07-02 11:00:00          403
# 2012-07-02 12:00:00          388
# 2012-07-02 13:00:00          410
# 2012-07-02 14:00:00          413
# 2012-07-02 15:00:00          410
# 2012-07-02 16:00:00          409
# 2012-07-02 17:00:00          396
# 2012-07-02 18:00:00          389
# 2012-07-02 19:00:00          387
# 2012-07-02 20:00:00          370
# 2012-07-02 21:00:00          345
# 2012-07-02 22:00:00          317
# 2012-07-02 23:00:00          296
# 2012-07-03 00:00:00          276
# 2012-07-03 01:00:00          271
# 2012-07-03 02:00:00          280
# 2012-07-03 03:00:00          298
# 2012-07-03 04:00:00          306
# 2012-07-03 05:00:00          295
# ...                          ...
# 2012-12-30 18:00:00          359
# 2012-12-30 19:00:00          354
# 2012-12-30 20:00:00          344
# 2012-12-30 21:00:00          328
# 2012-12-30 22:00:00          304
# 2012-12-30 23:00:00          301
# 2012-12-31 00:00:00          303
# 2012-12-31 01:00:00          314
# 2012-12-31 02:00:00          329
# 2012-12-31 03:00:00          330
# 2012-12-31 04:00:00          321
# 2012-12-31 05:00:00          301
# 2012-12-31 06:00:00          287
# 2012-12-31 07:00:00          289
# 2012-12-31 08:00:00          313
# 2012-12-31 09:00:00          317
# 2012-12-31 10:00:00          313
# 2012-12-31 11:00:00          309
# 2012-12-31 12:00:00          307
# 2012-12-31 13:00:00          300
# 2012-12-31 14:00:00          294
# 2012-12-31 15:00:00          298
# 2012-12-31 16:00:00          321
# 2012-12-31 17:00:00          369
# 2012-12-31 18:00:00          381
# 2012-12-31 19:00:00          375
# 2012-12-31 20:00:00          364
# 2012-12-31 21:00:00          350
# 2012-12-31 22:00:00          333
# 2012-12-31 23:00:00          348
#
# [4392 rows x 1 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-719bf0c0-5cff-44e5-a213-ad3a00a825e1" name="files[]" multiple disabled />
#      <output id="result-719bf0c0-5cff-44e5-a213-ad3a00a825e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving shikoku_electricity_2013.csv to shikoku_electricity_2013.csv

# %%
pd.read_csv('shikoku_electricity_2013.csv', skiprows=3, names=['DATE','TIME','consumption'],parse_dates={'date_hour':['DATE','TIME']}, index_col='date_hour')
# Out:
#                      consumption
# date_hour
# 2013-01-01 00:00:00          351
# 2013-01-01 01:00:00          356
# 2013-01-01 02:00:00          361
# 2013-01-01 03:00:00          355
# 2013-01-01 04:00:00          340
# 2013-01-01 05:00:00          315
# 2013-01-01 06:00:00          291
# 2013-01-01 07:00:00          286
# 2013-01-01 08:00:00          311
# 2013-01-01 09:00:00          315
# 2013-01-01 10:00:00          309
# 2013-01-01 11:00:00          294
# 2013-01-01 12:00:00          282
# 2013-01-01 13:00:00          271
# 2013-01-01 14:00:00          265
# 2013-01-01 15:00:00          268
# 2013-01-01 16:00:00          287
# 2013-01-01 17:00:00          323
# 2013-01-01 18:00:00          334
# 2013-01-01 19:00:00          331
# 2013-01-01 20:00:00          328
# 2013-01-01 21:00:00          315
# 2013-01-01 22:00:00          299
# 2013-01-01 23:00:00          300
# 2013-01-02 00:00:00          298
# 2013-01-02 01:00:00          306
# 2013-01-02 02:00:00          320
# 2013-01-02 03:00:00          319
# 2013-01-02 04:00:00          308
# 2013-01-02 05:00:00          287
# ...                          ...
# 2013-12-30 18:00:00          378
# 2013-12-30 19:00:00          371
# 2013-12-30 20:00:00          362
# 2013-12-30 21:00:00          345
# 2013-12-30 22:00:00          323
# 2013-12-30 23:00:00          323
# 2013-12-31 00:00:00          321
# 2013-12-31 01:00:00          328
# 2013-12-31 02:00:00          340
# 2013-12-31 03:00:00          341
# 2013-12-31 04:00:00          332
# 2013-12-31 05:00:00          306
# 2013-12-31 06:00:00          288
# 2013-12-31 07:00:00          287
# 2013-12-31 08:00:00          309
# 2013-12-31 09:00:00          311
# 2013-12-31 10:00:00          293
# 2013-12-31 11:00:00          281
# 2013-12-31 12:00:00          276
# 2013-12-31 13:00:00          270
# 2013-12-31 14:00:00          264
# 2013-12-31 15:00:00          269
# 2013-12-31 16:00:00          290
# 2013-12-31 17:00:00          331
# 2013-12-31 18:00:00          341
# 2013-12-31 19:00:00          335
# 2013-12-31 20:00:00          327
# 2013-12-31 21:00:00          312
# 2013-12-31 22:00:00          301
# 2013-12-31 23:00:00          310
#
# [8760 rows x 1 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5c9df086-655b-4d96-9182-5e9145c05879" name="files[]" multiple disabled />
#      <output id="result-5c9df086-655b-4d96-9182-5e9145c05879">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving shikoku_electricity_2014.csv to shikoku_electricity_2014.csv

# %%
pd.read_csv('shikoku_electricity_2014.csv', skiprows=3, names=['DATE','TIME','consumption'],parse_dates={'date_hour':['DATE','TIME']}, index_col='date_hour')
# Out:
#                      consumption
# date_hour
# 2014-01-01 00:00:00          314
# 2014-01-01 01:00:00          322
# 2014-01-01 02:00:00          334
# 2014-01-01 03:00:00          331
# 2014-01-01 04:00:00          320
# 2014-01-01 05:00:00          294
# 2014-01-01 06:00:00          270
# 2014-01-01 07:00:00          262
# 2014-01-01 08:00:00          279
# 2014-01-01 09:00:00          275
# 2014-01-01 10:00:00          264
# 2014-01-01 11:00:00          258
# 2014-01-01 12:00:00          259
# 2014-01-01 13:00:00          252
# 2014-01-01 14:00:00          249
# 2014-01-01 15:00:00          250
# 2014-01-01 16:00:00          267
# 2014-01-01 17:00:00          302
# 2014-01-01 18:00:00          313
# 2014-01-01 19:00:00          308
# 2014-01-01 20:00:00          304
# 2014-01-01 21:00:00          297
# 2014-01-01 22:00:00          280
# 2014-01-01 23:00:00          279
# 2014-01-02 00:00:00          278
# 2014-01-02 01:00:00          288
# 2014-01-02 02:00:00          306
# 2014-01-02 03:00:00          310
# 2014-01-02 04:00:00          301
# 2014-01-02 05:00:00          280
# ...                          ...
# 2014-12-30 18:00:00          346
# 2014-12-30 19:00:00          341
# 2014-12-30 20:00:00          332
# 2014-12-30 21:00:00          319
# 2014-12-30 22:00:00          303
# 2014-12-30 23:00:00          301
# 2014-12-31 00:00:00          302
# 2014-12-31 01:00:00          315
# 2014-12-31 02:00:00          333
# 2014-12-31 03:00:00          337
# 2014-12-31 04:00:00          330
# 2014-12-31 05:00:00          308
# 2014-12-31 06:00:00          292
# 2014-12-31 07:00:00          291
# 2014-12-31 08:00:00          307
# 2014-12-31 09:00:00          295
# 2014-12-31 10:00:00          278
# 2014-12-31 11:00:00          268
# 2014-12-31 12:00:00          263
# 2014-12-31 13:00:00          265
# 2014-12-31 14:00:00          265
# 2014-12-31 15:00:00          279
# 2014-12-31 16:00:00          304
# 2014-12-31 17:00:00          333
# 2014-12-31 18:00:00          336
# 2014-12-31 19:00:00          330
# 2014-12-31 20:00:00          321
# 2014-12-31 21:00:00          309
# 2014-12-31 22:00:00          300
# 2014-12-31 23:00:00          311
#
# [8760 rows x 1 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c39ab88-378e-4662-abb0-3a971c99f01a" name="files[]" multiple disabled />
#      <output id="result-2c39ab88-378e-4662-abb0-3a971c99f01a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving shikoku_electricity_2015.csv to shikoku_electricity_2015.csv

# %%
pd.read_csv('shikoku_electricity_2015.csv', skiprows=3, names=['DATE','TIME','consumption'],parse_dates={'date_hour':['DATE','TIME']}, index_col='date_hour')
# Out:
#                      consumption
# date_hour
# 2015-01-01 00:00:00          317
# 2015-01-01 01:00:00          328
# 2015-01-01 02:00:00          341
# 2015-01-01 03:00:00          341
# 2015-01-01 04:00:00          331
# 2015-01-01 05:00:00          308
# 2015-01-01 06:00:00          287
# 2015-01-01 07:00:00          285
# 2015-01-01 08:00:00          312
# 2015-01-01 09:00:00          322
# 2015-01-01 10:00:00          313
# 2015-01-01 11:00:00          305
# 2015-01-01 12:00:00          302
# 2015-01-01 13:00:00          298
# 2015-01-01 14:00:00          294
# 2015-01-01 15:00:00          299
# 2015-01-01 16:00:00          320
# 2015-01-01 17:00:00          355
# 2015-01-01 18:00:00          367
# 2015-01-01 19:00:00          363
# 2015-01-01 20:00:00          361
# 2015-01-01 21:00:00          350
# 2015-01-01 22:00:00          333
# 2015-01-01 23:00:00          337
# 2015-01-02 00:00:00          334
# 2015-01-02 01:00:00          334
# 2015-01-02 02:00:00          344
# 2015-01-02 03:00:00          341
# 2015-01-02 04:00:00          328
# 2015-01-02 05:00:00          307
# ...                          ...
# 2015-12-30 18:00:00          346
# 2015-12-30 19:00:00          343
# 2015-12-30 20:00:00          336
# 2015-12-30 21:00:00          323
# 2015-12-30 22:00:00          303
# 2015-12-30 23:00:00          300
# 2015-12-31 00:00:00          300
# 2015-12-31 01:00:00          309
# 2015-12-31 02:00:00          326
# 2015-12-31 03:00:00          330
# 2015-12-31 04:00:00          320
# 2015-12-31 05:00:00          292
# 2015-12-31 06:00:00          274
# 2015-12-31 07:00:00          274
# 2015-12-31 08:00:00          286
# 2015-12-31 09:00:00          276
# 2015-12-31 10:00:00          270
# 2015-12-31 11:00:00          269
# 2015-12-31 12:00:00          270
# 2015-12-31 13:00:00          272
# 2015-12-31 14:00:00          271
# 2015-12-31 15:00:00          274
# 2015-12-31 16:00:00          291
# 2015-12-31 17:00:00          327
# 2015-12-31 18:00:00          332
# 2015-12-31 19:00:00          327
# 2015-12-31 20:00:00          323
# 2015-12-31 21:00:00          309
# 2015-12-31 22:00:00          297
# 2015-12-31 23:00:00          302
#
# [8760 rows x 1 columns]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ce05d030-1f0b-408e-8dd7-cfc169d993b5" name="files[]" multiple disabled />
#      <output id="result-ce05d030-1f0b-408e-8dd7-cfc169d993b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving shikoku_electricity_2016.csv to shikoku_electricity_2016.csv

# %%
pd.read_csv('shikoku_electricity_2016.csv', skiprows=3, names=['DATE','TIME','consumption'],parse_dates={'date_hour':['DATE','TIME']}, index_col='date_hour')
# Out:
#                      consumption
# date_hour
# 2016-01-01 00:00:00          299
# 2016-01-01 01:00:00          311
# 2016-01-01 02:00:00          327
# 2016-01-01 03:00:00          332
# 2016-01-01 04:00:00          326
# 2016-01-01 05:00:00          304
# 2016-01-01 06:00:00          279
# 2016-01-01 07:00:00          270
# 2016-01-01 08:00:00          274
# 2016-01-01 09:00:00          263
# 2016-01-01 10:00:00          247
# 2016-01-01 11:00:00          240
# 2016-01-01 12:00:00          238
# 2016-01-01 13:00:00          234
# 2016-01-01 14:00:00          235
# 2016-01-01 15:00:00          240
# 2016-01-01 16:00:00          252
# 2016-01-01 17:00:00          285
# 2016-01-01 18:00:00          299
# 2016-01-01 19:00:00          299
# 2016-01-01 20:00:00          304
# 2016-01-01 21:00:00          300
# 2016-01-01 22:00:00          288
# 2016-01-01 23:00:00          288
# 2016-01-02 00:00:00          289
# 2016-01-02 01:00:00          298
# 2016-01-02 02:00:00          316
# 2016-01-02 03:00:00          320
# 2016-01-02 04:00:00          311
# 2016-01-02 05:00:00          290
# ...                          ...
# 2016-03-30 18:00:00          336
# 2016-03-30 19:00:00          335
# 2016-03-30 20:00:00          324
# 2016-03-30 21:00:00          305
# 2016-03-30 22:00:00          284
# 2016-03-30 23:00:00          273
# 2016-03-31 00:00:00          270
# 2016-03-31 01:00:00          283
# 2016-03-31 02:00:00          310
# 2016-03-31 03:00:00          324
# 2016-03-31 04:00:00          324
# 2016-03-31 05:00:00          309
# 2016-03-31 06:00:00          295
# 2016-03-31 07:00:00          287
# 2016-03-31 08:00:00          311
# 2016-03-31 09:00:00          325
# 2016-03-31 10:00:00          324
# 2016-03-31 11:00:00          320
# 2016-03-31 12:00:00          311
# 2016-03-31 13:00:00          331
# 2016-03-31 14:00:00          328
# 2016-03-31 15:00:00          317
# 2016-03-31 16:00:00          324
# 2016-03-31 17:00:00          326
# 2016-03-31 18:00:00          336
# 2016-03-31 19:00:00          329
# 2016-03-31 20:00:00          317
# 2016-03-31 21:00:00          298
# 2016-03-31 22:00:00          283
# 2016-03-31 23:00:00          274
#
# [2184 rows x 1 columns]

# %%
ed = [pd.read_csv('shikoku_electricity_%d.csv' % year, skiprows=3, names=['DATE','TIME','consumption'], parse_dates={'date_hour':['DATE','TIME']}, index_col='date_hour') for year in[2012, 2013, 2014, 2015, 2016]]

# %%
elec_data = pd.concat(ed)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 6))
delta = elec_data.index - pd.to_datetime('2012/07/01 00:00:00')
elec_data['time'] = delta.days + delta.seconds/3600.0/24.0

plt.scatter(elec_data['time'], elec_data['consumption'], s=0.1)
plt.xlabel('days from 2012/7/1')
plt.ylabel('electricity consumption(*10000 kwh)')

plt.savefig('7-4-1-1-graph.png')

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 6))
plt.hist(elec_data['consumption'], bins=50, color="gray")
plt.xlabel('electricity consumption(*10000 kwh)')
plt.ylabel('count')

plt.savefig('7-4-1-2-graph.png')
