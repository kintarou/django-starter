# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kintarou/django-starter/blob/dark-theme/Untitled0.ipynb)

# %%
import math
import matplotlib.pyplot as plt
g = 9.8

def draw_graph(x,y):
  plt.plot(x,y)
  plt.xlabel('x-coordinate')
  plt.ylabel('y-coordinate')
  plt.title('Projectile motion at different initiak velocities and angles')
  
def frange(start, final, interval):
  numbers=[]
  while start<final:
    numbers.append(start)
    start=start+interval
  return numbers

def draw_trajectory(u,theta,t_flight):
  x=[]
  y=[]
  intervals=frange(0,t_flight,0.001)
  for t in intervals:
    x.append(u*math.cos(theta)*t)
    y.append(u*math.sin(theta)*t-0.5*g*t*t)
  draw_graph(x,y)
             
if __name__ == '__main__':
  num_trajectories=int(input('How many trajectories? '))
  
  velocities=[]
  angles=[]
  for i in range(1,num_trajectories+1):
    v=input('Enter the initial velocity for trajectory {0}(m/s): '.format(i))
    theta=input('Enter the angle of projection for trajectory {0} (degrees):'.format(i))
    velocities.append(float(v))
    angles.append(math.radians(float(theta)))
    
  for i in range(num_trajectories):
    t_flight=2*velocities[i]*math.sin(angles[i])/g
    S_x=velocities[i]*math.cos(angles[i])*t_flight
    S_y=velocities[i]*math.sin(angles[i])*(t_flight/2)-(1/2)*g*(t_flight/2)**2
    print('Initial velocity: {0}Angle of Projection: {1}'.format(velocities[i],math.degrees(angles[i])))
    print('T: {0} S_x: {1} S_y: {2}'.format(t_flight, S_x, S_y))
    print()
    draw_trajectory(velocities[i], angles[i], t_flight)
    
  legends=[]
  for i in range(0, num_trajectories):
    legends.append('{0}-{1}'.format(velocities[i],math.degrees(angles[i])))
  plt.legend(legends)
  plt.show
# Out:
# How many trajectories? 5
# Enter the initial velocity for trajectory 1(m/s): 60
# Enter the angle of projection for trajectory 1 (degrees):30
# Enter the initial velocity for trajectory 2(m/s): 100
# Enter the angle of projection for trajectory 2 (degrees):20
# Enter the initial velocity for trajectory 3(m/s): 90
# Enter the angle of projection for trajectory 3 (degrees):60
# Enter the initial velocity for trajectory 4(m/s): 120
# Enter the angle of projection for trajectory 4 (degrees):80
# Enter the initial velocity for trajectory 5(m/s): 150
# Enter the angle of projection for trajectory 5 (degrees):75
# Initial velocity: 60.0Angle of Projection: 29.999999999999996
# T: 6.1224489795918355 S_x: 318.1317809820386 S_y: 45.91836734693876
#
# Initial velocity: 100.0Angle of Projection: 20.0
# T: 6.980002925013646 S_x: 655.905724169938 S_y: 59.682540020668846
#
# Initial velocity: 90.0Angle of Projection: 59.99999999999999
# T: 15.906589049101933 S_x: 715.7965072095872 S_y: 309.94897959183675
#
# Initial velocity: 120.0Angle of Projection: 80.0
# T: 24.11774089009489 S_x: 502.56021060098277 S_y: 712.54014641115
#
# Initial velocity: 150.0Angle of Projection: 75.0
# T: 29.569157947624536 S_x: 1147.9591836734692 S_y: 1071.06049962117
