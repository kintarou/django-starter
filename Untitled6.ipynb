# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/kintarou/django-starter/blob/dark-theme/Untitled6.ipynb)

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.formula.api as smf
# %precision 3
# %matplotlib inline

from google.colab import files
uploaded = files.upload()

beer = pd.read_csv("5-1-1-beer.csv")

resid = lm_model.resid

sns.distplot(resid, color = 'black')
# Out:
#      <input type="file" id="files-584a9728-dc2d-4e83-ad64-c534a034990e" name="files[]" multiple disabled />
#      <output id="result-584a9728-dc2d-4e83-ad64-c534a034990e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5-1-1-beer.csv to 5-1-1-beer (11).csv

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.formula.api as smf
# %precision 3
# %matplotlib inline

from google.colab import files
uploaded = files.upload()

beer = pd.read_csv("5-1-1-beer.csv")

resid = lm_model.resid
sns.jointplot(lm_model.fittedvalues, resid, joint_kws = {"color":"black"}, marginal_kws ={"color":"black"})
# Out:
#      <input type="file" id="files-2d41f135-5ec7-43a1-97e4-1b6aedbd3aad" name="files[]" multiple disabled />
#      <output id="result-2d41f135-5ec7-43a1-97e4-1b6aedbd3aad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5-1-1-beer.csv to 5-1-1-beer (13).csv

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %precision 3
# %matplotlib inline

from google.colab import files
uploaded = files.upload()

beer = pd.read_csv("5-1-1-beer.csv")

resid = lm_model.resid

fig = sm.qqplot(resid, line = "s")
# Out:
#      <input type="file" id="files-c362a655-5332-4b84-b0a6-36bdd800a81e" name="files[]" multiple disabled />
#      <output id="result-c362a655-5332-4b84-b0a6-36bdd800a81e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 5-1-1-beer.csv to 5-1-1-beer (14).csv

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %precision 3
# %matplotlib inline

from google.colab import files
uploaded = files.upload()

test_result = pd.read_csv("6-3-1-logistic-regression.csv")

mod_glm = smf.glm(formula = "result ~ hours", data = test_result, family = sm.families.Binomial()).fit()

sns.lmplot(x = "hours", y = "result", data = test_result, logistic = True, scatter_kws = {"color":"black"}, line_kws = {"color":"black"}, x_jitter= 0.1, y_jitter = 0.02)
# Out:
#      <input type="file" id="files-afc3edf7-3c5e-4aa9-a1c6-2cbd498a6598" name="files[]" multiple disabled />
#      <output id="result-afc3edf7-3c5e-4aa9-a1c6-2cbd498a6598">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 6-3-1-logistic-regression.csv to 6-3-1-logistic-regression (5).csv

# %%
df = sns.load_dataset("iris")

sns.pairplot(df, hue='species',
             palette={'setosa': 'red',
                      'versicolor': '#00ff00',
                      'virginica': 'blue'},kind='reg')

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.api as sm
import statsmodels.formula.api as smf
# %precision 3
# %matplotlib inline

from google.colab import files
uploaded = files.upload()

beer = pd.read_csv("6-5-1-poisson-regression.csv")


mod_pois = smf.glm("beer_number~temperature", beer, family = sm.families.Poisson()).fit

mod_pois_null = smf.glm("beer_number ~ 1" ,data = beer, family = sm.families.Poisson()).fit

x_plot = np.arange(0, 37)
pred = mod_pois.predict(pd.DataFrame({"temperature": x_plot}))

sns.lmplot(y = "beer_number", x = "temperature", data = beer, fit_reg = False, scatter_kws = {"color":"black"})
plt.plot(x_plot, pred, color = "black")

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import linear_model
# %precision 3
# %matplotlib inline

from google.colab import files
uploaded = files.upload()

X = pd.read_csv("7-3-1-large-data.csv")
X.head(3)
# Out:
#      <input type="file" id="files-fadc1c2b-3f1b-404e-8bd7-7bcd8d1e1b22" name="files[]" multiple disabled />
#      <output id="result-fadc1c2b-3f1b-404e-8bd7-7bcd8d1e1b22">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 7-3-1-large-data.csv to 7-3-1-large-data (1).csv
#       X_1     X_2     X_3     X_4     X_5     X_6     X_7     X_8     X_9  \
# 0  1.0000  0.5000  0.3333  0.2500  0.2000  0.1667  0.1429  0.1250  0.1111
# 1  0.5000  0.3333  0.2500  0.2000  0.1667  0.1429  0.1250  0.1111  0.1000
# 2  0.3333  0.2500  0.2000  0.1667  0.1429  0.1250  0.1111  0.1000  0.0909
#
#      X_10   ...      X_91    X_92    X_93    X_94    X_95    X_96    X_97  \
# 0  0.1000   ...    0.0110  0.0109  0.0108  0.0106  0.0105  0.0104  0.0103
# 1  0.0909   ...    0.0109  0.0108  0.0106  0.0105  0.0104  0.0103  0.0102
# 2  0.0833   ...    0.0108  0.0106  0.0105  0.0104  0.0103  0.0102  0.0101
#
#      X_98    X_99   X_100
# 0  0.0102  0.0101  0.0100
# 1  0.0101  0.0100  0.0099
# 2  0.0100  0.0099  0.0098
#
# [3 rows x 100 columns]

# %%
sp.mean(X, axis = 0)
X /= sp.std(X, ddof = 1, axis = 0)
sp.mean(X, axis = 0).head(3).round(3)
# Out:
# X_1    0.380
# X_2    0.530
# X_3    0.636
# dtype: float64

# %%
np.random.seed(1)
noise = sp.stats.norm.rvs(loc = 0, scale = 1, size = X.shape[0])
y = X.X_1 * 5 + noise

large_data = pd.concat([pd.DataFrame({"y":y}), X], axis = 1)
sns.jointplot(y ="y", x = "X_1", data = large_data, color = 'black')
